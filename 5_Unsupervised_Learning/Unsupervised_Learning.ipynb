# %%
from PIL import Image
from sklearn.cluster import KMeans

# %%
image = Image.open('dogs.jpeg')

# %%
from matplotlib import pyplot as plot

# %matplotlib inline

plot.imshow(image)

# %%
import numpy as np

image_np = np.asarray(image)

# %%
image_np.shape
# Out:
# (185, 272, 3)

# %%
# Normalize the image to fit into unsupervised model
image_np = image_np.reshape((185*272,3))

# %%
image_np.shape
# Out:
# (50320, 3)

# %%
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(image_np)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
labels = kmeans.predict(image_np)

# %%
# Construct back the image based on its original dimension
labels = labels.reshape((185,272))

# %%
# Results of the kmeans with 3 cluster
plot.imshow(labels)

# %%
centers = [centers.astype(int) for centers in kmeans.cluster_centers_]

# %%
blob = np.ones((100,100,3))

# %%
blob1 = blob * centers[0]

# %%
plot.imshow(blob1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
blob2 = blob * centers[1]
plot.imshow(blob2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
blob2=blob2.astype(int)
blob2
# Out:
# array([[[251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243],
#         ...,
#         [251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243]],
#
#        [[251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243],
#         ...,
#         [251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243]],
#
#        [[251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243],
#         ...,
#         [251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243]],
#
#        ...,
#
#        [[251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243],
#         ...,
#         [251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243]],
#
#        [[251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243],
#         ...,
#         [251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243]],
#
#        [[251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243],
#         ...,
#         [251, 247, 243],
#         [251, 247, 243],
#         [251, 247, 243]]])

# %%
blob3 = blob * centers[2]
plot.imshow(blob3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
centers
# Out:
# [array([210, 174, 143]), array([251, 247, 243]), array([29, 21, 20])]
